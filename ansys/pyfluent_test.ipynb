# %%
import ansys.fluent.core as pyfluent
import numpy as np

# %%
# solver = pyfluent.launch_fluent(mode="solver", show_gui=True)
# solver.tui.file.read_case('"D:/ANSYS Fluent Projects/V4F heat exchanger/fluent/V4F2_hx_MPE_x4_V2_CD-0.110.cas.h5"')

# %%
file_path = r'D:\ANSYS Fluent Projects\pvt_slice_outdoor\Fluent_GMI\server\server_info-34156.txt'

# %%
solver = pyfluent.connect_to_fluent(server_info_filepath=file_path) # créer une session : File -> Applications -> Server -> Start...
# Out:
# adjoint/                parallel/               server/
# define/                 parametric-study/       solve/
# display/                plot/                   surface/
# exit                    preferences/            turbo-workflow/
# file/                   print-license-usage     views/
# mesh/                   report/
#
# >
# /file> Output filename []
# Writing Settings file "CFD-settings.txt"...
# 	writing rp variables ... Done.
# 	writing domain variables ... Done.
# 	writing frame-corps.1 (type solid) (mixture) ... Done.
# 	writing frame-corps (type solid) (mixture) ... Done.
# 	writing pv-corps (type solid) (mixture) ... Done.
# 	writing cd-cd2 (type fluid) (mixture) ... Done.
# 	writing cd-cd1 (type fluid) (mixture) ... Done.
# 	writing cd-cd1:1 (type symmetry) (mixture) ... Done.
# 	writing pv_backsheet (type wall) (mixture) ... Done.
# 	writing hx_flat_yu_pv-pv_backsheet-cd-cd1-pv-corps (type wall) (mixture) ... Done.
# 	writing hx_flat_yd_pv-pv_backsheet-cd-cd1-pv-corps (type wall) (mixture) ... Done.
# 	writing pv_front (type wall) (mixture) ... Done.
# 	writing cd_fc (type pressure-inlet) (mixture) ... Done.
# 	writing cd_cd2_internal_zu (type interior) (mixture) ... Done.
# 	writing cd_roof (type wall) (mixture) ... Done.
# 	writing cd_cd2_internal_zd (type interior) (mixture) ... Done.
# 	writing cd2_symmetry_planes (type symmetry) (mixture) ... Done.
# 	writing cd2_horizontal_zu (type pressure-outlet) (mixture) ... Done.
# 	writing cd2_horizontal_zd (type pressure-inlet) (mixture) ... Done.
# 	writing cd2_wind (type pressure-outlet) (mixture) ... Done.
# 	writing frame_yd_1 (type wall) (mixture) ... Done.
# 	writing frame_yd_2 (type wall) (mixture) ... Done.
# 	writing frame_yu_1 (type wall) (mixture) ... Done.
# 	writing frame_yu_2 (type wall) (mixture) ... Done.
# 	writing frame_symmetry (type symmetry) (mixture) ... Done.
# 	writing frame_symmetry.1 (type symmetry) (mixture) ... Done.
# 	writing pv_symmetry (type symmetry) (mixture) ... Done.
# 	writing manifold_yu (type wall) (mixture) ... Done.
# 	writing hx_bend_yu_air (type wall) (mixture) ... Done.
# 	writing hx_bend_yu_pv (type wall) (mixture) ... Done.
# 	writing hx_flat_yu_air (type wall) (mixture) ... Done.
# 	writing hx_flat_yd_air (type wall) (mixture) ... Done.
# 	writing hx_bend_mid_air (type wall) (mixture) ... Done.
# 	writing hx_bend_mid_pv (type wall) (mixture) ... Done.
# 	writing hx_bend_yd_pv (type wall) (mixture) ... Done.
# 	writing hx_bend_yd_air (type wall) (mixture) ... Done.
# 	writing manifold_yd (type wall) (mixture) ... Done.
# 	writing hx_sides_1 (type wall) (mixture) ... Done.
# 	writing hx_sides_2 (type wall) (mixture) ... Done.
# 	writing hx_sides_3 (type wall) (mixture) ... Done.
# 	writing hx_sides_4 (type wall) (mixture) ... Done.
# 	writing interior--cd-cd1 (type interior) (mixture) ... Done.
# 	writing interior--pv-corps (type interior) (mixture) ... Done.
# 	writing interior--frame-corps (type interior) (mixture) ... Done.
# 	writing interior--frame-corps.1 (type interior) (mixture) ... Done.
# 	writing interior--cd-cd2 (type interior) (mixture) ... Done.
# 	writing pv_backsheet-shadow (type wall) (mixture) ... Done.
# 	writing pv_front-shadow (type wall) (mixture) ... Done.
# 	writing frame_yd_1-shadow (type wall) (mixture) ... Done.
# 	writing frame_yd_2-shadow (type wall) (mixture) ... Done.
# 	writing frame_yu_1-shadow (type wall) (mixture) ... Done.
# 	writing frame_yu_2-shadow (type wall) (mixture) ... Done.
# 	writing zones map name-id ... Done.
#
# /file>
# Writing Settings file "C:\Users\seagu\AppData\Local\Temp\2"...
# 	writing rp variables ... Done.
# 	writing domain variables ... Done.
# 	writing frame-corps.1 (type solid) (mixture) ... Done.
# 	writing frame-corps (type solid) (mixture) ... Done.
# 	writing pv-corps (type solid) (mixture) ... Done.
# 	writing cd-cd2 (type fluid) (mixture) ... Done.
# 	writing cd-cd1 (type fluid) (mixture) ... Done.
# 	writing cd-cd1:1 (type symmetry) (mixture) ... Done.
# 	writing pv_backsheet (type wall) (mixture) ... Done.
# 	writing hx_flat_yu_pv-pv_backsheet-cd-cd1-pv-corps (type wall) (mixture) ... Done.
# 	writing hx_flat_yd_pv-pv_backsheet-cd-cd1-pv-corps (type wall) (mixture) ... Done.
# 	writing pv_front (type wall) (mixture) ... Done.
# 	writing cd_fc (type pressure-inlet) (mixture) ... Done.
# 	writing cd_cd2_internal_zu (type interior) (mixture) ... Done.
# 	writing cd_roof (type wall) (mixture) ... Done.
# 	writing cd_cd2_internal_zd (type interior) (mixture) ... Done.
# 	writing cd2_symmetry_planes (type symmetry) (mixture) ... Done.
# 	writing cd2_horizontal_zu (type pressure-outlet) (mixture) ... Done.
# 	writing cd2_horizontal_zd (type pressure-inlet) (mixture) ... Done.
# 	writing cd2_wind (type pressure-outlet) (mixture) ... Done.
# 	writing frame_yd_1 (type wall) (mixture) ... Done.
# 	writing frame_yd_2 (type wall) (mixture) ... Done.
# 	writing frame_yu_1 (type wall) (mixture) ... Done.
# 	writing frame_yu_2 (type wall) (mixture) ... Done.
# 	writing frame_symmetry (type symmetry) (mixture) ... Done.
# 	writing frame_symmetry.1 (type symmetry) (mixture) ... Done.
# 	writing pv_symmetry (type symmetry) (mixture) ... Done.
# 	writing manifold_yu (type wall) (mixture) ... Done.
# 	writing hx_bend_yu_air (type wall) (mixture) ... Done.
# 	writing hx_bend_yu_pv (type wall) (mixture) ... Done.
# 	writing hx_flat_yu_air (type wall) (mixture) ... Done.
# 	writing hx_flat_yd_air (type wall) (mixture) ... Done.
# 	writing hx_bend_mid_air (type wall) (mixture) ... Done.
# 	writing hx_bend_mid_pv (type wall) (mixture) ... Done.
# 	writing hx_bend_yd_pv (type wall) (mixture) ... Done.
# 	writing hx_bend_yd_air (type wall) (mixture) ... Done.
# 	writing manifold_yd (type wall) (mixture) ... Done.
# 	writing hx_sides_1 (type wall) (mixture) ... Done.
# 	writing hx_sides_2 (type wall) (mixture) ... Done.
# 	writing hx_sides_3 (type wall) (mixture) ... Done.
# 	writing hx_sides_4 (type wall) (mixture) ... Done.
# 	writing interior--cd-cd1 (type interior) (mixture) ... Done.
# 	writing interior--pv-corps (type interior) (mixture) ... Done.
# 	writing interior--frame-corps (type interior) (mixture) ... Done.
# 	writing interior--frame-corps.1 (type interior) (mixture) ... Done.
# 	writing interior--cd-cd2 (type interior) (mixture) ... Done.
# 	writing pv_backsheet-shadow (type wall) (mixture) ... Done.
# 	writing pv_front-shadow (type wall) (mixture) ... Done.
# 	writing frame_yd_1-shadow (type wall) (mixture) ... Done.
# 	writing frame_yd_2-shadow (type wall) (mixture) ... Done.
# 	writing frame_yu_1-shadow (type wall) (mixture) ... Done.
# 	writing frame_yu_2-shadow (type wall) (mixture) ... Done.
# 	writing zones map name-id ... Done.
# Multicore SMT processors detected. Processor affinity set!
#
#        Clearing partially read grid.
#
# Reading from Seagull-3000:"D:/ANSYS Fluent Projects/pvt_slice_outdoor/Fluent_GMI/Mesh/V4.5NI_simplified_Vref_M1.msh.h5" in NODE0 mode ...
#   Reading mesh ...
#      3640105 cells,     5 cell zones ...
#         3018269 polyhedra cells,  zone id: 6593
#          607948 polyhedra cells,  zone id: 6596
#             537 polyhedra cells,  zone id: 6599
#             553 polyhedra cells,  zone id: 6602
#           12798 polyhedra cells,  zone id: 6605
#     19731359 faces,    39 face zones ...
#           73934 polygonal interior faces,  zone id: 6604
#            2030 polygonal interior faces,  zone id: 6601
#            1968 polygonal interior faces,  zone id: 6598
#         3642850 polygonal interior faces,  zone id: 6595
#        15365650 polygonal interior faces,  zone id: 6592
#           90283 polygonal wall faces,  zone id: 303
#           90033 polygonal wall faces,  zone id: 302
#            8761 polygonal wall faces,  zone id: 301
#            7931 polygonal wall faces,  zone id: 307
#            8750 polygonal wall faces,  zone id: 306
#            7940 polygonal wall faces,  zone id: 300
#           19210 polygonal wall faces,  zone id: 305
#           17904 polygonal wall faces,  zone id: 304
#            2174 polygonal wall faces,  zone id: 291
#            4121 polygonal wall faces,  zone id: 299
#            4145 polygonal wall faces,  zone id: 308
#            7892 polygonal wall faces,  zone id: 310
#            7861 polygonal wall faces,  zone id: 311
#            7879 polygonal wall faces,  zone id: 312
#            8015 polygonal wall faces,  zone id: 309
#             428 polygonal internal faces,  zone id: 318
#           47100 polygonal symmetry faces,  zone id: 317
#             356 polygonal pressure-outlet faces,  zone id: 316
#             347 polygonal pressure-inlet faces,  zone id: 315
#             102 polygonal pressure-outlet faces,  zone id: 314
#            6278 polygonal symmetry faces,  zone id: 313
#            6495 polygonal symmetry faces,  zone id: 298
#              34 polygonal symmetry faces,  zone id: 297
#              34 polygonal symmetry faces,  zone id: 296
#             625 polygonal wall faces,  zone id: 295
#              48 polygonal wall faces,  zone id: 294
#             641 polygonal wall faces,  zone id: 293
#              48 polygonal wall faces,  zone id: 292
#              67 polygonal internal faces,  zone id: 290
#              80 polygonal pressure-inlet faces,  zone id: 289
#           78733 polygonal wall faces,  zone id: 288
#           90053 polygonal wall faces,  zone id: 287
#           89908 polygonal wall faces,  zone id: 286
#           30651 polygonal wall faces,  zone id: 285
#     14898003 nodes,    22 node zones ...
#
# Building...
#      mesh
# 	distributing mesh
# 		parts................,
# 		faces................,
# 		nodes................,
# 		cells................,
#         bandwidth reduction using Reverse Cuthill-McKee: 225844/11004 = 20.5238
#      materials,
#      interface,
#      domains,
#      zones,
# 	frame_yu_2-shadow
# 	frame_yu_1-shadow
# 	frame_yd_2-shadow
# 	frame_yd_1-shadow
# 	pv_front-shadow
# 	pv_backsheet-shadow
# 	Skipping thread 143 of domain 1 (not referenced by grid).
# 	Skipping thread 145 of domain 1 (not referenced by grid).
# 	Skipping thread 147 of domain 1 (not referenced by grid).
# 	Skipping thread 149 of domain 1 (not referenced by grid).
# 	Skipping thread 151 of domain 1 (not referenced by grid).
# 	Skipping thread 153 of domain 1 (not referenced by grid).
# 	Skipping thread 155 of domain 1 (not referenced by grid).
# 	Skipping thread 157 of domain 1 (not referenced by grid).
# 	Skipping thread 159 of domain 1 (not referenced by grid).
# 	Skipping thread 161 of domain 1 (not referenced by grid).
# 	Skipping thread 163 of domain 1 (not referenced by grid).
# 	Skipping thread 165 of domain 1 (not referenced by grid).
# 	Skipping thread 167 of domain 1 (not referenced by grid).
# 	Skipping thread 169 of domain 1 (not referenced by grid).
# 	Skipping thread 180 of domain 1 (not referenced by grid).
# 	Skipping thread 181 of domain 1 (not referenced by grid).
# 	Skipping thread 182 of domain 1 (not referenced by grid).
# 	Skipping thread 183 of domain 1 (not referenced by grid).
# 	Skipping thread 184 of domain 1 (not referenced by grid).
# 	Skipping thread 185 of domain 1 (not referenced by grid).
# 	Skipping thread 186 of domain 1 (not referenced by grid).
# 	Skipping thread 187 of domain 1 (not referenced by grid).
# 	Skipping thread 188 of domain 1 (not referenced by grid).
# 	Skipping thread 189 of domain 1 (not referenced by grid).
# 	Skipping thread 190 of domain 1 (not referenced by grid).
# 	Skipping thread 191 of domain 1 (not referenced by grid).
# 	Skipping thread 192 of domain 1 (not referenced by grid).
# 	Skipping thread 193 of domain 1 (not referenced by grid).
# 	Skipping thread 194 of domain 1 (not referenced by grid).
# 	Skipping thread 195 of domain 1 (not referenced by grid).
# 	Skipping thread 196 of domain 1 (not referenced by grid).
# 	Skipping thread 197 of domain 1 (not referenced by grid).
# 	Skipping thread 198 of domain 1 (not referenced by grid).
# 	Skipping thread 199 of domain 1 (not referenced by grid).
# 	Skipping thread 200 of domain 1 (not referenced by grid).
# 	Skipping thread 201 of domain 1 (not referenced by grid).
# 	Skipping thread 202 of domain 1 (not referenced by grid).
# 	Skipping thread 203 of domain 1 (not referenced by grid).
# 	Skipping thread 204 of domain 1 (not referenced by grid).
# 	Skipping thread 205 of domain 1 (not referenced by grid).
# 	Skipping thread 206 of domain 1 (not referenced by grid).
# 	Skipping thread 207 of domain 1 (not referenced by grid).
# 	Skipping thread 208 of domain 1 (not referenced by grid).
# 	Skipping thread 209 of domain 1 (not referenced by grid).
# 	Skipping thread 210 of domain 1 (not referenced by grid).
# 	Skipping thread 211 of domain 1 (not referenced by grid).
# 	Skipping thread 212 of domain 1 (not referenced by grid).
# 	Skipping thread 213 of domain 1 (not referenced by grid).
# 	Skipping thread 214 of domain 1 (not referenced by grid).
# 	Skipping thread 215 of domain 1 (not referenced by grid).
# 	Skipping thread 216 of domain 1 (not referenced by grid).
# 	Skipping thread 217 of domain 1 (not referenced by grid).
# 	Skipping thread 218 of domain 1 (not referenced by grid).
# 	Skipping thread 219 of domain 1 (not referenced by grid).
# 	Skipping thread 220 of domain 1 (not referenced by grid).
# 	Skipping thread 221 of domain 1 (not referenced by grid).
# 	Skipping thread 222 of domain 1 (not referenced by grid).
# 	Skipping thread 223 of domain 1 (not referenced by grid).
# 	Skipping thread 224 of domain 1 (not referenced by grid).
# 	Skipping thread 225 of domain 1 (not referenced by grid).
# 	Skipping thread 226 of domain 1 (not referenced by grid).
# 	Skipping thread 227 of domain 1 (not referenced by grid).
# 	Skipping thread 228 of domain 1 (not referenced by grid).
# 	Skipping thread 229 of domain 1 (not referenced by grid).
# 	Skipping thread 230 of domain 1 (not referenced by grid).
# 	Skipping thread 231 of domain 1 (not referenced by grid).
# 	Skipping thread 232 of domain 1 (not referenced by grid).
# 	Skipping thread 233 of domain 1 (not referenced by grid).
# 	Skipping thread 234 of domain 1 (not referenced by grid).
# 	Skipping thread 235 of domain 1 (not referenced by grid).
# 	Skipping thread 236 of domain 1 (not referenced by grid).
# 	Skipping thread 237 of domain 1 (not referenced by grid).
# 	Skipping thread 238 of domain 1 (not referenced by grid).
# 	Skipping thread 239 of domain 1 (not referenced by grid).
# 	Skipping thread 240 of domain 1 (not referenced by grid).
# 	Skipping thread 241 of domain 1 (not referenced by grid).
# 	Skipping thread 242 of domain 1 (not referenced by grid).
# 	Skipping thread 243 of domain 1 (not referenced by grid).
# 	Skipping thread 244 of domain 1 (not referenced by grid).
# 	Skipping thread 245 of domain 1 (not referenced by grid).
# 	Skipping thread 246 of domain 1 (not referenced by grid).
# 	Skipping thread 247 of domain 1 (not referenced by grid).
# 	Skipping thread 248 of domain 1 (not referenced by grid).
# 	Skipping thread 249 of domain 1 (not referenced by grid).
# 	Skipping thread 250 of domain 1 (not referenced by grid).
# 	Skipping thread 251 of domain 1 (not referenced by grid).
# 	Skipping thread 252 of domain 1 (not referenced by grid).
# 	Skipping thread 253 of domain 1 (not referenced by grid).
# 	Skipping thread 254 of domain 1 (not referenced by grid).
# 	Skipping thread 255 of domain 1 (not referenced by grid).
# 	Skipping thread 256 of domain 1 (not referenced by grid).
# 	Skipping thread 257 of domain 1 (not referenced by grid).
# 	Skipping thread 258 of domain 1 (not referenced by grid).
# 	Skipping thread 259 of domain 1 (not referenced by grid).
# 	Skipping thread 260 of domain 1 (not referenced by grid).
# 	Skipping thread 261 of domain 1 (not referenced by grid).
# 	Skipping thread 262 of domain 1 (not referenced by grid).
# 	Skipping thread 263 of domain 1 (not referenced by grid).
# 	Skipping thread 264 of domain 1 (not referenced by grid).
# 	Skipping thread 265 of domain 1 (not referenced by grid).
# 	Skipping thread 266 of domain 1 (not referenced by grid).
# 	Skipping thread 267 of domain 1 (not referenced by grid).
# 	Skipping thread 268 of domain 1 (not referenced by grid).
# 	Skipping thread 269 of domain 1 (not referenced by grid).
# 	Skipping thread 270 of domain 1 (not referenced by grid).
# 	Skipping thread 271 of domain 1 (not referenced by grid).
# 	Skipping thread 272 of domain 1 (not referenced by grid).
# 	Skipping thread 273 of domain 1 (not referenced by grid).
# 	Skipping thread 274 of domain 1 (not referenced by grid).
# 	Skipping thread 275 of domain 1 (not referenced by grid).
# 	Skipping thread 276 of domain 1 (not referenced by grid).
# 	Skipping thread 277 of domain 1 (not referenced by grid).
# 	Skipping thread 278 of domain 1 (not referenced by grid).
# 	Skipping thread 279 of domain 1 (not referenced by grid).
# 	Skipping thread 280 of domain 1 (not referenced by grid).
# 	Skipping thread 281 of domain 1 (not referenced by grid).
# 	Skipping thread 282 of domain 1 (not referenced by grid).
# 	Skipping thread 283 of domain 1 (not referenced by grid).
# 	Skipping thread 284 of domain 1 (not referenced by grid).
# 	interior--cd-cd2
# 	interior--frame-corps.1
# 	interior--frame-corps
# 	interior--pv-corps
# 	interior--cd-cd1
# 	hx_flat_yd_air
# 	hx_flat_yu_air
# 	hx_bend_yu_pv
# 	hx_bend_yd_air
# 	hx_bend_yd_pv
# 	hx_bend_yu_air
# 	hx_bend_mid_pv
# 	hx_bend_mid_air
# 	cd_roof
# 	manifold_yu
# 	manifold_yd
# 	hx_sides_2
# 	hx_sides_3
# 	hx_sides_4
# 	hx_sides_1
# 	cd_cd2_internal_zd
# 	cd_symmetry_planes
# 	cd2_horizontal_zd
# 	cd2_wind
# 	cd2_horizontal_zu
# 	cd2_symmetry_planes
# 	pv_symmetry
# 	frame_symmetry.1
# 	frame_symmetry
# 	frame_yu_2
# 	frame_yu_1
# 	frame_yd_2
# 	frame_yd_1
# 	cd_cd2_internal_zu
# 	cd_fc
# 	pv_front
# 	hx_flat_yd_pv-pv_backsheet-cd-cd1-pv-corps
# 	hx_flat_yu_pv-pv_backsheet-cd-cd1-pv-corps
# 	pv_backsheet
# 	cd-cd1
# 	cd-cd2
# 	pv-corps
# 	frame-corps
# 	frame-corps.1
#      parallel,
# Done.
# Mesh is now scaled to meters.
#
# Preparing mesh for display...
# Done.
#  Setting zone id of frame-corps.1 to 644.
#  Setting zone id of frame-corps to 641.
#  Setting zone id of pv-corps to 638.
#  Setting zone id of cd-cd2 to 73636.
#  Setting zone id of cd-cd1 to 73637.
#  Setting zone id of pv_backsheet to 73639.
#  Setting zone id of hx_flat_yu_pv-pv_backsheet-cd-cd1-pv-corps to 73640.
#  Setting zone id of hx_flat_yd_pv-pv_backsheet-cd-cd1-pv-corps to 73641.
#  Setting zone id of pv_front to 122.
#  Setting zone id of cd_fc to 73606.
#  Setting zone id of cd_cd2_internal_zu to 73607.
#  Setting zone id of frame_yd_1 to 73651.
#  Setting zone id of frame_yd_2 to 73652.
#  Setting zone id of frame_yu_1 to 73653.
#  Setting zone id of frame_yu_2 to 73654.
#  Setting zone id of frame_symmetry to 73655.
#  Setting zone id of frame_symmetry.1 to 73656.
#  Setting zone id of pv_symmetry to 73657.
#  Setting zone id of cd2_symmetry_planes to 73617.
#  Setting zone id of cd2_horizontal_zu to 73618.
#  Setting zone id of cd2_wind to 73620.
#  Setting zone id of cd2_horizontal_zd to 73619.
#  Setting zone id of cd_cd2_internal_zd to 73616.
#  Setting zone id of hx_sides_1 to 73668.
#  Setting zone id of hx_sides_4 to 73671.
#  Setting zone id of hx_sides_3 to 73670.
#  Setting zone id of hx_sides_2 to 73669.
#  Setting zone id of manifold_yd to 73667.
#  Setting zone id of manifold_yu to 73658.
#  Setting zone id of cd_roof to 73624.
#  Setting zone id of hx_bend_mid_air to 73663.
#  Setting zone id of hx_bend_mid_pv to 73664.
#  Setting zone id of hx_bend_yu_air to 73659.
#  Setting zone id of hx_bend_yd_pv to 73665.
#  Setting zone id of hx_bend_yd_air to 73666.
#  Setting zone id of hx_bend_yu_pv to 73660.
#  Setting zone id of hx_flat_yu_air to 73661.
#  Setting zone id of hx_flat_yd_air to 73662.
#  Setting zone id of interior--cd-cd1 to 73672.
#  Setting zone id of interior--pv-corps to 637.
#  Setting zone id of interior--frame-corps to 640.
#  Setting zone id of interior--frame-corps.1 to 643.
#  Setting zone id of interior--cd-cd2 to 73676.
#  Setting zone id of pv_backsheet-shadow to 73677.
#  Setting zone id of pv_front-shadow to 2.
#  Setting zone id of frame_yd_1-shadow to 73679.
#  Setting zone id of frame_yd_2-shadow to 73680.
#  Setting zone id of frame_yu_1-shadow to 73681.
#  Setting zone id of frame_yu_2-shadow to 73682.
# Done.
#
# Setting frame-corps.1 (mixture) ... Done.
# Setting frame-corps (mixture) ... Done.
# Setting pv-corps (mixture) ... Done.
# Setting cd-cd2 (mixture) ... Done.
# Setting cd-cd1 (mixture) ... Done.
# No zone with name cd-cd1:1 (type symmetry) (mixture), skipped.
# Setting pv_backsheet (mixture) ... Done.
# Setting hx_flat_yu_pv-pv_backsheet-cd-cd1-pv-corps (mixture) ... Done.
# Setting hx_flat_yd_pv-pv_backsheet-cd-cd1-pv-corps (mixture) ... Done.
# Setting pv_front (mixture) ... Done.
# Setting cd_fc (mixture) ... Done.
# Setting cd_cd2_internal_zu (mixture) ... Done.
# Setting cd_roof (mixture) ... Done.
# Setting cd_cd2_internal_zd (mixture) ... Done.
# Setting cd2_symmetry_planes (mixture) ... Done.
# Setting cd2_horizontal_zu (mixture) ... Done.
# Setting cd2_horizontal_zd (mixture) (zone type changed to pressure-inlet) ... Done.
# Setting cd2_wind (mixture) (zone type changed to pressure-outlet) ... Done.
# Setting frame_yd_1 (mixture) ... Done.
# Setting frame_yd_2 (mixture) ... Done.
# Setting frame_yu_1 (mixture) ... Done.
# Setting frame_yu_2 (mixture) ... Done.
# Setting frame_symmetry (mixture) ... Done.
# Setting frame_symmetry.1 (mixture) ... Done.
# Setting pv_symmetry (mixture) ... Done.
# Setting manifold_yu (mixture) ... Done.
# Setting hx_bend_yu_air (mixture) ... Done.
# Setting hx_bend_yu_pv (mixture) ... Done.
# Setting hx_flat_yu_air (mixture) ... Done.
# Setting hx_flat_yd_air (mixture) ... Done.
# Setting hx_bend_mid_air (mixture) ... Done.
# Setting hx_bend_mid_pv (mixture) ... Done.
# Setting hx_bend_yd_pv (mixture) ... Done.
# Setting hx_bend_yd_air (mixture) ... Done.
# Setting manifold_yd (mixture) ... Done.
# Setting hx_sides_1 (mixture) ... Done.
# Setting hx_sides_2 (mixture) ... Done.
# Setting hx_sides_3 (mixture) ... Done.
# Setting hx_sides_4 (mixture) ... Done.
# Setting interior--cd-cd1 (mixture) ... Done.
# Setting interior--pv-corps (mixture) ... Done.
# Setting interior--frame-corps (mixture) ... Done.
# Setting interior--frame-corps.1 (mixture) ... Done.
# Setting interior--cd-cd2 (mixture) ... Done.
# Setting pv_backsheet-shadow (mixture) ... Done.
# Setting pv_front-shadow (mixture) ... Done.
# Setting frame_yd_1-shadow (mixture) ... Done.
# Setting frame_yd_2-shadow (mixture) ... Done.
# Setting frame_yu_1-shadow (mixture) ... Done.
# Setting frame_yu_2-shadow (mixture) ... Done.
#
# Checking newly created zones for preferred zone IDs...
# Warning: reading 32 partition grid onto 16 compute node machine.
#          Combining every 2 partitions.
#   Done.
#
#
# Following contexts active in the case file have been de-activated because of their current context control conditions:
# "coupled-pseudo-transient"
# Found new zone. Assigning default settings to cd_symmetry_planes (type symmetry).
#
# auto-save/              read-field-functions    start-transcript
# binary-legacy-files?    read-injections         stop-journal
# cff-files?              read-journal            stop-macro
# cffio-options/          read-macros             stop-transcript
# confirm-overwrite?      read-profile            table-manager/
# define-macro            read-settings           transient-export/
# execute-macro           read-surface-clusters   write-boundary-mesh
# export/                 read-transient-table    write-case
# import/                 read-viewfactors        write-cleanup-script
# interpolate/            replace-mesh            write-field-functions
# load-act-tool           set-batch-options       write-injections
# parametric-project/     set-idle-timeout        write-macros
# read-case               set-tui-version         write-pdat?
# read-case-data          show-configuration      write-settings
# read-case-info          solution-files/
# read-data               start-journal
#
# /file> Input filename []
# Reading Settings file "CFD-settings.txt"...
#
#
# Error: sopeninputfile: unable to open file for input
# Error Object: "CFD-settings.txt"
#
# /file> invalid command [settings-CFD.txt]
#
# /file> Input filename []
# Reading Settings file "settings-CFD.txt"...
#
#
# Error: sopeninputfile: unable to open file for input
# Error Object: "settings-CFD.txt"
#
# /file>
# The following expressions could not be deleted as they are currently being used:
# 	rho_air
# 	hint_man
# 	e_man
# 	e_hx
# 	Temperature_field
# 	T_fluid_m
# 	T_amb
#
#
# Reading journal file D:\ANSYS Fluent Projects\temp\create_named_expression.txt...
#
# > define/named-expressions/add "rho_air"Object by name rho_air already exists!
#  definition "1.244822623 invalid command ["1.244822623]
# [kg/m^3]" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_field.txt...
#
# > define/named-expressions/add "T_amb"Object by name T_amb already exists!
#  definition Object by name definition already exists!
# "nan" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_named_expression.txt...
#
# > define/named-expressions/add "e_hx"Object by name e_hx already exists!
#  definition Object by name definition already exists!
# "0.0035 [m]"Invalid python string quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_named_expression.txt...
#
# > define/named-expressions/add "e_man"Object by name e_man already exists!
#  definition Object by name definition already exists!
# "0.002 [m]"Invalid python string quitObject by name quit already exists!
#
# Reading journal file D:\ANSYS Fluent Projects\temp\create_named_expression.txt...
#
# > define/named-expressions/add "hint_hx" definition "720.0 [W/(m^2 K)]" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_named_expression.txt...
#
# > define/named-expressions/add "hint_man"Object by name hint_man already exists!
#  definition Object by name definition already exists!
# "250.0 [W/(m^2 K)]"Invalid python string quitObject by name quit already exists!
#
# Reading journal file D:\ANSYS Fluent Projects\temp\create_named_expression.txt...
#
# > define/named-expressions/add "convergence_criteria" definition "0.1 [W]" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_field.txt...
#
# > define/named-expressions/add "nb_hx" definition "5.0" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_named_expression.txt...
#
# > define/named-expressions/add "theta" definition "0.7853981633974483 [rad]" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_named_expression.txt...
#
# > define/named-expressions/add "theta_1" definition "0.6941174435181449 [rad]" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_named_expression.txt...
#
# > define/named-expressions/add "L_1" definition "0.06 [m]" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_named_expression.txt...
#
# > define/named-expressions/add "T_fluid_in_1" definition "1.0 [K]" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_named_expression.txt...
#
# > define/named-expressions/add "a_f_1" definition "1.0 [m^-1]" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_named_expression.txt...
#
# > define/named-expressions/add "b_f_1" definition "1.0 [K m^-1]" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_named_expression.txt...
#
# > define/named-expressions/add "theta_2" definition "0.0 [rad]" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_named_expression.txt...
#
# > define/named-expressions/add "L_2" definition "0.6715 [m]" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_named_expression.txt...
#
# > define/named-expressions/add "T_fluid_in_2" definition "1.0 [K]" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_named_expression.txt...
#
# > define/named-expressions/add "a_f_2" definition "1.0 [m^-1]" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_named_expression.txt...
#
# > define/named-expressions/add "b_f_2" definition "1.0 [K m^-1]" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_named_expression.txt...
#
# > define/named-expressions/add "theta_3" definition "0.0 [rad]" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_named_expression.txt...
#
# > define/named-expressions/add "L_3" definition "0.1149177 [m]" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_named_expression.txt...
#
# > define/named-expressions/add "T_fluid_in_3" definition "1.0 [K]" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_named_expression.txt...
#
# > define/named-expressions/add "a_f_3" definition "1.0 [m^-1]" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_named_expression.txt...
#
# > define/named-expressions/add "b_f_3" definition "1.0 [K m^-1]" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_named_expression.txt...
#
# > define/named-expressions/add "theta_4" definition "0.0 [rad]" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_named_expression.txt...
#
# > define/named-expressions/add "L_4" definition "0.6715 [m]" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_named_expression.txt...
#
# > define/named-expressions/add "T_fluid_in_4" definition "1.0 [K]" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_named_expression.txt...
#
# > define/named-expressions/add "a_f_4" definition "1.0 [m^-1]" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_named_expression.txt...
#
# > define/named-expressions/add "b_f_4" definition "1.0 [K m^-1]" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_named_expression.txt...
#
# > define/named-expressions/add "theta_5" definition "-0.6941174435181451 [rad]" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_named_expression.txt...
#
# > define/named-expressions/add "L_5" definition "0.06 [m]" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_named_expression.txt...
#
# > define/named-expressions/add "T_fluid_in_5" definition "1.0 [K]" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_named_expression.txt...
#
# > define/named-expressions/add "a_f_5" definition "1.0 [m^-1]" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_named_expression.txt...
#
# > define/named-expressions/add "b_f_5" definition "1.0 [K m^-1]" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_named_expression.txt...
#
# > define/named-expressions/add "T_fluid_in_6" definition "1.0 [K]" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_named_expression.txt...
#
# > define/named-expressions/add "Qdot_top_rad" definition "1.0 [W]" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_field.txt...
#
# > define/named-expressions/add "T_field_1" definition "(T_fluid_in_1 + (b_f_1 / a_f_1)) * exp(a_f_1 * (-(0.6397073394462182)*(Position.y-(0 [m])) + (0.7686185789184653)*(Position.z-(0 [m])))) - (b_f_1 / a_f_1)" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_field.txt...
#
# > define/named-expressions/add "T_mean_1" definition "((T_fluid_in_1 + (b_f_1 / a_f_1))/(a_f_1*L_1)) * (exp(a_f_1 * L_1) - 1)- (b_f_1 / a_f_1)" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_field.txt...
#
# > define/named-expressions/add "T_field_2" definition "(T_fluid_in_2 + (b_f_2 / a_f_2)) * exp(a_f_2 * (-(0.0)*(Position.y-(-0.03838244036677309 [m])) + (1.0)*(Position.z-(0.04611711473510792 [m])))) - (b_f_2 / a_f_2)" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_field.txt...
#
# > define/named-expressions/add "T_mean_2" definition "((T_fluid_in_2 + (b_f_2 / a_f_2))/(a_f_2*L_2)) * (exp(a_f_2 * L_2) - 1)- (b_f_2 / a_f_2)" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_field.txt...
#
# > define/named-expressions/add "T_field_3" definition "(T_fluid_in_3 + (b_f_3 / a_f_3)) * exp(a_f_3 * (-(0.0)*(Position.y-(-0.03838244036677309 [m])) + (1.0)*(Position.z-(0.7176171147351079 [m])))) - (b_f_3 / a_f_3)" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_field.txt...
#
# > define/named-expressions/add "T_mean_3" definition "((T_fluid_in_3 + (b_f_3 / a_f_3))/(a_f_3*L_3)) * (exp(a_f_3 * L_3) - 1)- (b_f_3 / a_f_3)" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_field.txt...
#
# > define/named-expressions/add "T_field_4" definition "(T_fluid_in_4 + (b_f_4 / a_f_4)) * exp(a_f_4 * (-(0.0)*(Position.y-(-0.03838244036677309 [m])) + (1.0)*(Position.z-(0.8325348147351079 [m])))) - (b_f_4 / a_f_4)" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_field.txt...
#
# > define/named-expressions/add "T_mean_4" definition "((T_fluid_in_4 + (b_f_4 / a_f_4))/(a_f_4*L_4)) * (exp(a_f_4 * L_4) - 1)- (b_f_4 / a_f_4)" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_field.txt...
#
# > define/named-expressions/add "T_field_5" definition "(T_fluid_in_5 + (b_f_5 / a_f_5)) * exp(a_f_5 * (-(-0.6397073394462184)*(Position.y-(-0.03838244036677309 [m])) + (0.7686185789184651)*(Position.z-(1.504034814735108 [m])))) - (b_f_5 / a_f_5)" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\create_field.txt...
#
# > define/named-expressions/add "T_mean_5" definition "((T_fluid_in_5 + (b_f_5 / a_f_5))/(a_f_5*L_5)) * (exp(a_f_5 * L_5) - 1)- (b_f_5 / a_f_5)" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\change_gravity.txt...
#
# > define/operating-conditions/gravity yes 0 6.9367175234400325 6.9367175234400325 quit
# Reading journal file D:\ANSYS Fluent Projects\temp\change_named_expression.txt...
#
# > define/named-expressions/edit "T_amb" definition "273.15 [K]" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\change_named_expression.txt...
#
# > define/named-expressions/edit "convergence_criteria" definition "0.1 [W]" quit
# The following properties are modified for the hx_bend_mid_air
#                      Temperature                        __expr__ T_mean_3
#
# The following properties are modified for the hx_bend_mid_pv
#                      Temperature                        __expr__ T_mean_3
#
# The following properties are modified for the hx_bend_yd_air
#                      Temperature                       __expr__ T_field_5
#
# The following properties are modified for the hx_bend_yd_pv
#                      Temperature                       __expr__ T_field_5
#
# The following properties are modified for the hx_bend_yd_air
#
# The following properties are modified for the hx_bend_yd_pv
#
# The following properties are modified for the hx_bend_yu_air
#                      Temperature                       __expr__ T_field_1
#
# The following properties are modified for the hx_bend_yu_pv
#                      Temperature                       __expr__ T_field_1
#
# The following properties are modified for the hx_bend_yu_air
#
# The following properties are modified for the hx_bend_yu_pv
#
# The Following zones cannot be edited with "hx_flat_yu_air" as those are either two sided or having solid adjacent zone and "hx_flat_yu_air" is single sided with adjacent fluid zone type
#    hx_flat_yu_pv-pv_backsheet-cd-cd1-pv-corps
# The following properties are modified for the hx_flat_yu_air
#                      Temperature                       __expr__ T_field_2
#
# The following expressions could not be deleted as they are currently being used:
# 	Temperature_field
#
#
# The following properties are modified for the hx_sides_1
#                      Temperature                    __expr__ T_fluid_mean
#
# The following properties are modified for the hx_sides_2
#                      Temperature                    __expr__ T_fluid_mean
#
# The following properties are modified for the hx_sides_3
#                      Temperature                    __expr__ T_fluid_mean
#
# The following properties are modified for the hx_sides_4
#                      Temperature                    __expr__ T_fluid_mean
# Reading journal file D:\ANSYS Fluent Projects\temp\change_gravity.txt...
#
# > define/operating-conditions/gravity yes 0 6.9367175234400325 6.9367175234400325 quit
# Reading journal file D:\ANSYS Fluent Projects\temp\change_named_expression.txt...
#
# > define/named-expressions/edit "T_amb" definition "273.15 [K]" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\change_named_expression.txt...
#
# Reading journal file D:\ANSYS Fluent Projects\temp\change_gravity.txt...
#
# > define/operating-conditions/gravity yes 0 6.9367175234400325 6.9367175234400325 quit
# Reading journal file D:\ANSYS Fluent Projects\temp\change_named_expression.txt...
#
# > define/named-expressions/edit "T_amb" definition "273.15 [K]" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\change_named_expression.txt...
#
# > define/named-expressions/edit "convergence_criteria" definition "0.1 [W]" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\change_gravity.txt...
#
# > define/operating-conditions/gravity yes 0 6.9367175234400325 6.9367175234400325 quit
# Reading journal file D:\ANSYS Fluent Projects\temp\change_named_expression.txt...
#
# > define/named-expressions/edit "T_amb" definition "273.15 [K]" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\change_named_expression.txt...
#
# > define/named-expressions/edit "convergence_criteria" definition "0.1 [W]" quit
# Reading journal file D:\ANSYS Fluent Projects\temp\initialize.txt...
#
# > /file/set-tui-version "22.2"
#
# > (cx-gui-do cx-activate-item "Ribbon*Frame1*Frame5(Solution)*Table1*Table3(Initialization)*ButtonBox1(Method)*PushButton4(Options)")
#
#
#
# > (cx-gui-do cx-set-list-selections "Solution Initialization*Table1*DropDownList1(Compute from)" '( cd_fc))
#
#
#
# > (cx-gui-do cx-activate-item "Solution Initialization*Table1*DropDownList1(Compute from)")
#
#
#
# > (cx-gui-do cx-set-real-entry-list "Solution Initialization*Table1*Table7(Initial Values)*RealEntry1(Gauge Pressure)" '( 0))
#
#
#
# > (cx-gui-do cx-activate-item "Solution Initialization*Table1*Table7(Initial Values)*RealEntry1(Gauge Pressure)")
#
#
#
# > (cx-gui-do cx-activate-item "Solution Initialization*Table1*Frame9*PushButton1(Initialize)")
#
# Attempting to read S2S file : D:/ANSYS Fluent Projects/pvt_slice_outdoor/mesh/V4.5NI_simplified_4MPE_r60_wbox_z45.s2s.h5
# Reading "D:/ANSYS Fluent Projects/pvt_slice_outdoor/mesh/V4.5NI_simplified_4MPE_r60_wbox_z45.s2s.h5"...
#
# ==============================================================================
#
# Node 5: Process 32164: Received signal SIGSEGV.
#
# ==============================================================================
#
# ===================================================================================
# =   BAD TERMINATION OF ONE OF YOUR APPLICATION PROCESSES
# =   RANK 0 PID 31668 RUNNING AT Seagull-3000
# =   EXIT STATUS: -1 (ffffffff)
# ===================================================================================
#
# ===================================================================================
# =   BAD TERMINATION OF ONE OF YOUR APPLICATION PROCESSES
# =   RANK 1 PID 52532 RUNNING AT Seagull-3000
# =   EXIT STATUS: -1 (ffffffff)
# ===================================================================================
#
# ===================================================================================
# =   BAD TERMINATION OF ONE OF YOUR APPLICATION PROCESSES
# =   RANK 2 PID 37096 RUNNING AT Seagull-3000
# =   EXIT STATUS: -1 (ffffffff)
# ===================================================================================
#
# ===================================================================================
# =   BAD TERMINATION OF ONE OF YOUR APPLICATION PROCESSES
# =   RANK 3 PID 42116 RUNNING AT Seagull-3000
# =   EXIT STATUS: -1 (ffffffff)
# ===================================================================================
#
# ===================================================================================
# =   BAD TERMINATION OF ONE OF YOUR APPLICATION PROCESSES
# =   RANK 4 PID 40584 RUNNING AT Seagull-3000
# =   EXIT STATUS: -1 (ffffffff)
# ===================================================================================
#
# ===================================================================================
# =   BAD TERMINATION OF ONE OF YOUR APPLICATION PROCESSES
# =   RANK 6 PID 13632 RUNNING AT Seagull-3000
# =   EXIT STATUS: -1 (ffffffff)
# ===================================================================================
#
# ===================================================================================
# =   BAD TERMINATION OF ONE OF YOUR APPLICATION PROCESSES
# =   RANK 7 PID 28912 RUNNING AT Seagull-3000
# =   EXIT STATUS: -1 (ffffffff)
# ===================================================================================
#
# ===================================================================================
# =   BAD TERMINATION OF ONE OF YOUR APPLICATION PROCESSES
# =   RANK 8 PID 31384 RUNNING AT Seagull-3000
# =   EXIT STATUS: -1 (ffffffff)
# ===================================================================================
#
# ===================================================================================
# =   BAD TERMINATION OF ONE OF YOUR APPLICATION PROCESSES
# =   RANK 9 PID 44768 RUNNING AT Seagull-3000
# =   EXIT STATUS: -1 (ffffffff)
# ===================================================================================
#
# ===================================================================================
# =   BAD TERMINATION OF ONE OF YOUR APPLICATION PROCESSES
# =   RANK 10 PID 26064 RUNNING AT Seagull-3000
# =   EXIT STATUS: -1 (ffffffff)
# ===================================================================================
#
# ===================================================================================
# =   BAD TERMINATION OF ONE OF YOUR APPLICATION PROCESSES
# =   RANK 11 PID 2784 RUNNING AT Seagull-3000
# =   EXIT STATUS: -1 (ffffffff)
# ===================================================================================
#
# ===================================================================================
# =   BAD TERMINATION OF ONE OF YOUR APPLICATION PROCESSES
# =   RANK 13 PID 37996 RUNNING AT Seagull-3000
# =   EXIT STATUS: -1 (ffffffff)
# ===================================================================================
#
# ===================================================================================
# =   BAD TERMINATION OF ONE OF YOUR APPLICATION PROCESSES
# =   RANK 14 PID 35392 RUNNING AT Seagull-3000
# =   EXIT STATUS: -1 (ffffffff)
# ===================================================================================
#
# ===================================================================================
# =   BAD TERMINATION OF ONE OF YOUR APPLICATION PROCESSES
# =   RANK 15 PID 20076 RUNNING AT Seagull-3000
# =   EXIT STATUS: -1 (ffffffff)
# ===================================================================================
#  The fl process could not be started.
#
# Error: Error reading "D:/ANSYS Fluent Projects/pvt_slice_outdoor/mesh/V4.5NI_simplified_4MPE_r60_wbox_z45.s2s.h5".
# Error Object: #f
#
#
# Warning: An error or interrupt occurred while reading the journal file.
# Some commands may not have been completed.
#
#
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# /file>
# ...
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available
#
# Error: Cortex received a fatal signal (SEGMENTATION VIOLATION).
# Error Object: ()
#
# >
# No error handler available

# %%
tui = solver.tui

# %%
solver.solution.run_calculation.iterate(number_of_iterations=5)
# Out:
#   iter  continuity  x-velocity  y-velocity  z-velocity      energy           k       omega  report-hx_     time/iter
#      1  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00  1.7820e-03  8.1372e+00  4.3679e+05              0:00:05    5
#      2  0.0000e+00  0.0000e+00  0.0000e+00  6.4534e-01  9.0293e-04  8.1791e-01  4.5948e-01              0:00:05    4
#
#  Reversed flow on 306 faces (100.0% area) of pressure-inlet 73619.
#
#  Reversed flow on 174 faces (100.0% area) of pressure-inlet 73606.
#
#  Reversed flow on 139 faces (57.1% area) of pressure-outlet 73620.
#
#  Reversed flow on 141 faces (100.0% area) of pressure-outlet 73618.
#      3  1.0000e+00  7.3718e-04  2.8040e-03  2.3125e-02  8.4536e-04  6.3631e-01  4.2562e-01              0:00:03    3
#
#  Reversed flow on 306 faces (100.0% area) of pressure-inlet 73619.
#
#  Reversed flow on 174 faces (100.0% area) of pressure-inlet 73606.
#
#  Reversed flow on 165 faces (68.0% area) of pressure-outlet 73620.
#
#  Reversed flow on 141 faces (100.0% area) of pressure-outlet 73618.
#      4  9.8961e-01  4.2356e-04  2.7973e-03  9.1301e-03  8.1969e-04  3.6438e-01  3.7124e-01              0:00:02    2
#
#  Reversed flow on 306 faces (100.0% area) of pressure-inlet 73619.
#
#  Reversed flow on 174 faces (100.0% area) of pressure-inlet 73606.
#
#  Reversed flow on 182 faces (75.4% area) of pressure-outlet 73620.
#
#  Reversed flow on 141 faces (100.0% area) of pressure-outlet 73618.
#      5  8.8222e-01  2.6867e-04  2.2769e-03  4.8865e-03  7.9700e-04  2.7959e-01  3.0178e-01  2.7521e+02  0:00:01    1
#
#  Reversed flow on 306 faces (100.0% area) of pressure-inlet 73619.
#
#  Reversed flow on 174 faces (100.0% area) of pressure-inlet 73606.
#
#  Reversed flow on 199 faces (82.7% area) of pressure-outlet 73620.
#
#  Reversed flow on 141 faces (100.0% area) of pressure-outlet 73618.
#      6  7.4969e-01  1.8313e-04  1.8653e-03  3.2540e-03  7.6360e-04  2.3019e-01  2.2184e-01              0:00:00    0
# Adjoint Solver is activated.
#
# Reading journal file D:\ANSYS Fluent Projects\temp\change_named_expression.txt...
#
# > define/named-expressions/edit "T_amb" definition "290 [K]" quitadjoint/                parallel/               server/
# define/                 parametric-study/       solve/
# display/                plot/                   surface/
# exit                    preferences/            turbo-workflow/
# file/                   print-license-usage     views/
# mesh/                   report/
#
# >
# /define>
# Type "?<command>" for help on a specific command.
# Type "?" to enter help mode, and "q" to exit help mode.
#
# The commands below are available in this menu.
# Those followed by "*" are unavailable with the current settings.
#
# beta-feature-access                             overset-interfaces/
# boundary-conditions/                            parameters/
# curvilinear-coordinate-system/                  periodic-conditions/*
# custom-field-functions/                         phases/*
# dynamic-mesh/                                   physics*
# enable-mesh-morpher-optimizer?                  profiles/
# gap-model/                                      reference-frames/
# injections/                                     set-unit-system
# materials/                                      solution-strategy/
# mesh-interfaces/                                spectral/*
# mixing-planes/                                  turbo-model/
# models/                                         units
# named-expressions/                              user-defined/
# operating-conditions/                           virtual-boundary/*
#
# /define>
# /define/boundary-conditions>
# Type "?<command>" for help on a specific command.
# Type "?" to enter help mode, and "q" to exit help mode.
#
# The commands below are available in this menu.
# Those followed by "*" are unavailable with the current settings.
#
# advanced/*                                      openchannel-threads*
# axis*                                           outflow*
# bc-settings/                                    outlet-vent*
# copy-bc                                         overset*
# degassing*                                      perforated-walls/
# exhaust-fan*                                    periodic*
# fan*                                            porous-jump*
# fluid                                           pressure-far-field*
# geometry*                                       pressure-inlet
# impedance-data-fitting/                         pressure-outlet
# inlet-vent*                                     radiator*
# intake-fan*                                     rans-les-interface*
# interface*                                      recirculation-inlet*
# interior*                                       recirculation-outlet*
# knudsen-number-calculator*                      rename-zone/
# list-zones                                      set/
# mass-flow-inlet*                                shadow*
# mass-flow-outlet*                               solid
# modify-zones/                                   symmetry
# network*                                        target-mass-flow-rate-settings/
# network-end*                                    velocity-inlet*
# non-overlapping-zone-name*                      wall
# non-reflecting-bc/                              zone-name
# open-channel-wave-settings*                     zone-type
#
# /define/boundary-conditions>   id  name                       type                material              kind
# ----  -------------------------  ------------------  --------------------  ----
#  644  frame-corps.1              solid               aluminum              cell
#  641  frame-corps                solid               aluminum              cell
#  638  pv-corps                   solid               pv-glass-glass        cell
# 73636  cd-cd2                     fluid               air                   cell
# 73637  cd-cd1                     fluid               air                   cell
# 73638  cd-cd1:1                   symmetry                                  face
# 73639  pv_backsheet               wall                air                   face
# 73640  hx_flat_yu_pv-pv_backsheet-cd-cd1-pv-corps  wall                pv-glass-glass        face
# 73641  hx_flat_yd_pv-pv_backsheet-cd-cd1-pv-corps  wall                pv-glass-glass        face
#  122  pv_front                   wall                air                   face
# 73606  cd_fc                      pressure-inlet                            face
# 73607  cd_cd2_internal_zu         interior                                  face
# 73624  cd_roof                    wall                air                   face
# 73616  cd_cd2_internal_zd         interior                                  face
# 73617  cd2_symmetry_planes        symmetry                                  face
# 73618  cd2_horizontal_zu          pressure-outlet                           face
# 73619  cd2_horizontal_zd          pressure-inlet                            face
# 73620  cd2_wind                   pressure-outlet                           face
# 73651  frame_yd_1                 wall                aluminum              face
# 73652  frame_yd_2                 wall                air                   face
# 73653  frame_yu_1                 wall                aluminum              face
# 73654  frame_yu_2                 wall                air                   face
# 73655  frame_symmetry             symmetry                                  face
# 73656  frame_symmetry.1           symmetry                                  face
# 73657  pv_symmetry                symmetry                                  face
# 73658  manifold_yu                wall                air                   face
# 73659  hx_bend_yu_air             wall                air                   face
# 73660  hx_bend_yu_pv              wall                air                   face
# 73661  hx_flat_yu_air             wall                air                   face
# 73662  hx_flat_yd_air             wall                air                   face
# 73663  hx_bend_mid_air            wall                air                   face
# 73664  hx_bend_mid_pv             wall                air                   face
# 73665  hx_bend_yd_pv              wall                air                   face
# 73666  hx_bend_yd_air             wall                air                   face
# 73667  manifold_yd                wall                air                   face
# 73668  hx_sides_1                 wall                air                   face
# 73669  hx_sides_2                 wall                air                   face
# 73670  hx_sides_3                 wall                air                   face
# 73671  hx_sides_4                 wall                air                   face
# 73672  interior--cd-cd1           interior                                  face
#  637  interior--pv-corps         interior                                  face
#  640  interior--frame-corps      interior                                  face
#  643  interior--frame-corps.1    interior                                  face
# 73676  interior--cd-cd2           interior                                  face
# 73677  pv_backsheet-shadow        wall                pv-glass-glass        face
#    2  pv_front-shadow            wall                pv-glass-glass        face
# 73679  frame_yd_1-shadow          wall                pv-glass-glass        face
# 73680  frame_yd_2-shadow          wall                aluminum              face
# 73681  frame_yu_1-shadow          wall                pv-glass-glass        face
# 73682  frame_yu_2-shadow          wall                aluminum              face
#
# /define/boundary-conditions>
# Type "?<command>" for help on a specific command.
# Type "?" to enter help mode, and "q" to exit help mode.
#
# The commands below are available in this menu.
# Those followed by "*" are unavailable with the current settings.
#
# advanced/*                                      openchannel-threads*
# axis*                                           outflow*
# bc-settings/                                    outlet-vent*
# copy-bc                                         overset*
# degassing*                                      perforated-walls/
# exhaust-fan*                                    periodic*
# fan*                                            porous-jump*
# fluid                                           pressure-far-field*
# geometry*                                       pressure-inlet
# impedance-data-fitting/                         pressure-outlet
# inlet-vent*                                     radiator*
# intake-fan*                                     rans-les-interface*
# interface*                                      recirculation-inlet*
# interior*                                       recirculation-outlet*
# knudsen-number-calculator*                      rename-zone/
# list-zones                                      set/
# mass-flow-inlet*                                shadow*
# mass-flow-outlet*                               solid
# modify-zones/                                   symmetry
# network*                                        target-mass-flow-rate-settings/
# network-end*                                    velocity-inlet*
# non-overlapping-zone-name*                      wall
# non-reflecting-bc/                              zone-name
# open-channel-wave-settings*                     zone-type
#
# /define/boundary-conditions> (pv_backsheet hx_flat_yu_pv-pv_backsheet-cd-cd1-pv-corps hx_flat_yd_pv-pv_backsheet-cd-cd1-pv-corps pv_front cd_roof frame_yd_1 frame_yd_2 frame_yu_1 frame_yu_2 manifold_yu hx_bend_yu_air hx_bend_yu_pv hx_flat_yu_air hx_flat_yd_air hx_bend_mid_air hx_bend_mid_pv hx_bend_yd_pv hx_bend_yd_air manifold_yd hx_sides_1 hx_sides_2 hx_sides_3 hx_sides_4 pv_backsheet-shadow pv_front-shadow frame_yd_1-shadow frame_yd_2-shadow frame_yu_1-shadow frame_yu_2-shadow)
# zone id/name [pv_backsheet] Invalid zone.
# zone id/name [pv_backsheet]
# Error: eval: unbound variable
# Error Object: hx_bend_yu_air
# Invalid length
#
# Error: eval: unbound variable
# Error Object: wall
# Invalid length
#
# Error: eval: unbound variable
# Error Object: air
# Invalid length
#
# Error: eval: unbound variable
# Error Object: face
# Invalid length
# Wall Thickness (constant or expresssion) (in [m]) ["e_hx"] Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Please answer y[es] or n[o].
# Use Profile for Heat Generation Rate? [no] Heat Generation Rate (constant or expresssion) (in [W/m^3]) [0]
# Error: eval: unbound variable
# Error Object: no
# Invalid heat-generation-rate
# Heat Generation Rate (constant or expresssion) (in [W/m^3]) [0] material-name [aluminum]: Change current value? [no] Thermal BC Type [temperature]: Change current value? [no] Use Profile for Temperature? [no] Temperature (constant or expresssion) (in [K]) ["Temperature_field"]
# Error: eval: unbound variable
# Error Object: quit
# Invalid temperature
# Temperature (constant or expresssion) (in [K]) ["Temperature_field"]
# Error: eval: unbound variable
# Error Object: quit
# Invalid temperature
# Temperature (constant or expresssion) (in [K]) ["Temperature_field"] Enable shell conduction? [no] Wall Motion [motion-bc-stationary]: Change current value? [no] Shear Boundary Condition [shear-bc-noslip]: Change current value? [no] Wall Surface Roughness [rough-bc-standard]: Change current value? [no] Use Profile for Internal Emissivity? [no] Internal Emissivity (constant or expresssion) [1] Use Profile for Wall Roughness Height? [no] The current case and data have not been saved.
# OK to discard? [cancel] Shutting down Server...

# %%
fluid_name = 'water-liquid'
myfluid = solver.setup.materials.fluid[fluid_name]
rho = myfluid.density()['constant']

list_Vdot = np.array([10, 30, 60, 100, 150, 210])/304 # L/h ; débit dans un riser (d'où le /304)
list_mdot = list_Vdot/3600000 * rho

for mdot in list_mdot[4:5] :
    tui.define.parameters.input_parameters.edit(f"mdot mdot {mdot}")
    solver.solution.initialization.standard_initialize()
    solver.solution.initialization.standard_initialize()
    solver.solution.run_calculation.iterate(number_of_iterations=100)

# %%
list_mdot

# %%
tui.results.report.surface_integrals.__eq__

# %%
solver.solution.report_definitions.compute(report_defs=["mass_flow_rate"])

# %%
solver.solution.initialization.hybrid_initialize()

# %%
import ansys.tools.protoc_helper.proto_provider

# %%
solver.exit()
